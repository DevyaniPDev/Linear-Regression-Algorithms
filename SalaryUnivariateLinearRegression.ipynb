# %% [markdown]
# <a href="https://colab.research.google.com/github/DevyaniPDev/Linear-Regression-Algorithms/blob/main/SalaryUnivariateLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  #for scientifical computation
import pandas as pd #for data organisation and manipulation
import matplotlib.pyplot as plt #for visualization
import seaborn as sns #for visualization

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.shape
# Out:
# (30, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.nunique()
# Out:
# YearsExperience    28
# Salary             30
# dtype: int64

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [YearsExperience, Salary]
# Index: []

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# Visual Analysis of data

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.distplot(x=data.Salary)

plt.subplot(1,2,2)
sns.boxplot(x=data.Salary)
plt.show()
# Out:
# /tmp/ipython-input-523716128.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.Salary)

# %%
data.Salary.describe()
# Out:
# count        30.000000
# mean      76003.000000
# std       27414.429785
# min       37731.000000
# 25%       56720.750000
# 50%       65237.000000
# 75%      100544.750000
# max      122391.000000
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.scatterplot(data.Salary)
# Out:
# <Axes: ylabel='Salary'>

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.distplot(x=data.YearsExperience)

plt.subplot(1,2,2)
sns.boxplot(x=data.YearsExperience)
plt.show()
# Out:
# /tmp/ipython-input-3140393262.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.YearsExperience)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('YearsExperience vs Salary')
sns.scatterplot(x=data.YearsExperience, y=data.Salary)
# Out:
# <Axes: title={'center': 'YearsExperience vs Salary'}, xlabel='YearsExperience', ylabel='Salary'>

# %%
#plt.figure(figsize=(10,15))
sns.heatmap(data.corr(),annot=True, cmap='YlGnBu')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
#from re import X
X=data.drop('Salary', axis=1)
y = data['Salary']
X.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
print(X_train.shape, X_test.shape)
# Out:
# (22, 1) (8, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
print("Train Accuracy:", r2_score(lr.predict(X_train),y_train))
print("Test Accuracy:", r2_score(lr.predict(X_test),y_test))
# Out:
# Train Accuracy: 0.9533048696126197
# Test Accuracy: 0.9346100018376171

# %% [markdown]
# This model is good fit
