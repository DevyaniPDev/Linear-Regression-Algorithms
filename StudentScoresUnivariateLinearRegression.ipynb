# %% [markdown]
# <a href="https://colab.research.google.com/github/DevyaniPDev/Linear-Regression-Algorithms/blob/main/StudentScoresUnivariateLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  #for scientifical computation
import pandas as pd #for data organisation and manipulation
import matplotlib.pyplot as plt #for visualization
import seaborn as sns #for visualization

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/All csv files/ScoresForStudent.csv')

# %%
data.head()
# Out:
#    StudentID  Hours_Studied  Exam_Score
# 0          1            1.5          35
# 1          2            2.0          37
# 2          3            2.5          45
# 3          4            3.0          48
# 4          5            3.5          52

# %%
data.tail()
# Out:
#     StudentID  Hours_Studied  Exam_Score
# 15         16            9.0          87
# 16         17            9.5          89
# 17         18           10.0          93
# 18         19           10.5          95
# 19         20           11.0          98

# %%
data.shape
# Out:
# (20, 2)

# %%
data.nunique()
# Out:
# StudentID        20
# Hours_Studied    20
# Exam_Score       20
# dtype: int64

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [StudentID, Hours_Studied, Exam_Score]
# Index: []

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data=data.drop('StudentID',axis=1)
data.head()
# Out:
#    Hours_Studied  Exam_Score
# 0            1.5          35
# 1            2.0          37
# 2            2.5          45
# 3            3.0          48
# 4            3.5          52

# %%
data.isnull().sum()
# Out:
# Hours_Studied    0
# Exam_Score       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Hours_Studied', 'Exam_Score'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hours_Studied  20 non-null     float64
#  1   Exam_Score     20 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 452.0 bytes

# %%
data.describe()
# Out:
#        Hours_Studied  Exam_Score
# count       20.00000   20.000000
# mean         6.25000   69.350000
# std          2.95804   19.453791
# min          1.50000   35.000000
# 25%          3.87500   53.500000
# 50%          6.25000   71.500000
# 75%          8.62500   85.500000
# max         11.00000   98.000000

# %% [markdown]
# Visual Analysis of data

# %%
plt.title('Exam Score Distribution plot')
sns.distplot(x=data.Exam_Score)
plt.show()
# Out:
# /tmp/ipython-input-3081350369.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.Exam_Score)

# %%
plt.title('Exam Score box plot')
sns.boxplot(x=data.Exam_Score)
plt.show()

# %%
plt.title('Hours Studies Distribution plot')
sns.distplot(x=data.Hours_Studied)
plt.show()
# Out:
# /tmp/ipython-input-1892424775.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.Hours_Studied)

# %%
plt.title('Hours Studies Box plot')
sns.boxplot(x=data.Hours_Studied)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Hours Studies vs Exam Score')
sns.scatterplot(x=data.Hours_Studied, y=data.Exam_Score)
# Out:
# <Axes: title={'center': 'Hours Studies vs Exam Score'}, xlabel='Hours_Studied', ylabel='Exam_Score'>

# %%
sns.heatmap(data.corr(),annot=True, cmap='YlGnBu')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
X=data.drop('Exam_Score', axis=1)
y = data['Exam_Score']

X.head()
# Out:
#    Hours_Studied
# 0            1.5
# 1            2.0
# 2            2.5
# 3            3.0
# 4            3.5

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
print(X_train.shape, X_test.shape)
# Out:
# (15, 1) (5, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
print("Train Accuracy:", r2_score(lr.predict(X_train),y_train))
print("Test Accuracy:", r2_score(lr.predict(X_test),y_test))
# Out:
# Train Accuracy: 0.993862114505623
# Test Accuracy: 0.9694215670437377

# %% [markdown]
# This is good fit
